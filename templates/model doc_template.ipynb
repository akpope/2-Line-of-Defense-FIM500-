# %% [markdown]
# ### Project Title (include your name, project/group name and the date)

# %% [markdown]
# #### *i. Brief Background/Introduction*
#
# (establish a quick synopsis of the project and what you created and it's business contexts)

# %% [markdown]
# #### *ii. Problem Statement and Business Context*
#
# (introduce your problem statement and how it relates to a banking operation/business)

# %% [markdown]
# #### *iii. Scope of Model*
#
# (speak about the scope of the model)

# %% [markdown]
# #### *iv. Model Outline and Assumptions*
#
# (give some background/math on the choice of the model and the assumptions made when creating the model)

# %% [markdown]
# #### *v. Model Implementation*
#
# (how you want someone to implement your model)

# %% [markdown]
# #### *vi. Limitations of Model and Ongoing Monitoring*
#
# (limitations for your model and future adaptations that might need to be made later down the road)
